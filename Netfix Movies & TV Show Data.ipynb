# %% [markdown]
# # Netflix Movies & TV Shows

# %%
#Importing the dataset
import pandas as pd
data = pd.read_csv(r"C:\Users\USER\Downloads\netflix_titles.csv~\netflix_titles.csv")

# %%
data
# Out:
#      show_id category                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head()
# Out:
#   show_id category                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.tail()
# Out:
#      show_id category        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'category', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# category        object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   category      8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#Duplicate records
data.head()
# Out:
#   show_id category                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, category, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates()
# Out:
#      show_id category                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Null Values

# %%
data.head()
# Out:
#   show_id category                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.isnull()
# Out:
#       show_id  category  title  director   cast  country  date_added  \
# 0       False     False  False     False   True    False       False
# 1       False     False  False      True  False    False       False
# 2       False     False  False     False  False     True       False
# 3       False     False  False      True   True     True       False
# 4       False     False  False      True  False    False       False
# ...       ...       ...    ...       ...    ...      ...         ...
# 8802    False     False  False     False  False    False       False
# 8803    False     False  False      True   True     True       False
# 8804    False     False  False     False  False    False       False
# 8805    False     False  False     False  False    False       False
# 8806    False     False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# category           0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Show Null value with Heat-Map

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Year whichis the highest number of TV shows & Movies were released

# %%
data.dtypes
# Out:
# show_id         object
# category        object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id category                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# category                object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#Total Movies & TV shows are in the dataset

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.groupby('category').category.count()
# Out:
# category
# Movie      6131
# TV Show    2676
# Name: category, dtype: int64

# %%
data['category'] = data['category'].astype('category')  
sns.countplot(x='category', data=data)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
#All the Movies that were released in year 2021

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data['Year']=data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['category']=='Movie')&(data['Year']==2021)]
# Out:
#      show_id category                                           title  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 6         s7    Movie                My Little Pony: A New Generation
# 7         s8    Movie                                         Sankofa
# 9        s10    Movie                                    The Starling
# 12       s13    Movie                                    Je Suis Karl
# ...      ...      ...                                             ...
# 8187   s8188    Movie                          The American President
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8461   s8462    Movie                               The Polar Express
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# ...

# %%
#The Titles of all the TV Shows that were released in Korea only

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data[(data['category']=='TV Show')&(data['country']=='South Korea')]['title']
# Out:
# 104             Tayo the Little Bus
# 124     Pororo - The Little Penguin
# 289               The Crowned Clown
# 456                Her Private Life
# 545            YooHoo to the Rescue
#                    ...
# 8117                          Suits
# 8257                   The Cravings
# 8379            The Lady in Dignity
# 8575                This Is My Love
# 8684                        Vroomiz
# Name: title, Length: 158, dtype: object

# %%
#Top 10 Directors who give the highest number of TV Shows & Movies to Netflix.

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
#All the records where "Ctegory is Movie & Type is Comedies" or "Country is United kigdom".

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['category']=='Movie') & (data['listed_in']=='Comedies')]
# Out:
#      show_id category                                   title  \
# 27       s28    Movie                               Grown Ups
# 152     s153    Movie           Janoskians: Untold and Untrue
# 182     s183    Movie             Welcome Home Roscoe Jenkins
# 342     s343    Movie                             Major Payne
# 348     s349    Movie                                    Poms
# ...      ...      ...                                     ...
# 8420   s8421    Movie              The Men Who Stare at Goats
# 8433   s8434    Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537    Movie                       The Trip to Spain
# 8608   s8609    Movie                        Total Frat Movie
# 8730   s8731    Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# ...

# %%
data[(data['category']=='Movie') & (data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]
# Out:
#      show_id category                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
#Number of Movies/ TV shows Tom Cruise was cast

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[data['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, category, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
data_new=data.dropna()

# %%
data_new.head(2)
# Out:
#   show_id category                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# 7  United States, Ghana, Burkina Faso, United Kin...  24-Sep-21          1993
# 8                                     United Kingdom  24-Sep-21          2021
#
#   rating   duration                                         listed_in  \
# 7  TV-MA    125 min  Dramas, Independent Movies, International Movies
# 8  TV-14  9 Seasons                      British TV Shows, Reality TV
#
#                                          description     Date_N    Year
# 7  On a photo shoot in Ghana, an American model s... 2021-09-24  2021.0
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id category     title              director  \
# 341     s342    Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255    Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 341    1-Aug-21          1999      R  189 min  Dramas, Independent Movies
# 1254   1-Mar-21          1988      R  134 min      Classic Movies, Dramas
#
#                                             description     Date_N    Year
# 341   Through chance, history and divine interventio... 2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021.0

# %%
#The different Ratings defined by Netflix

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#Number of Movies got the 'TV-14' rating in Canada

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['category']=='Movie') & (data['rating']=='TV-14')].shape
# Out:
# (1427, 14)

# %%
data[(data['category']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')]
# Out:
#      show_id category                                        title  \
# 157     s158    Movie                                     Level 16
# 1279   s1280    Movie   Made You Look: A True Story About Fake Art
# 2769   s2770    Movie               There's Something in the Water
# 3424   s3425    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973    Movie                             #cats_the_mewvie
# 5973   s5974    Movie                                        #Roxy
# 6192   s6193    Movie                               At First Light
# 6537   s6538    Movie                   Counterfeiting in Suburbia
# 7334   s7335    Movie                            Long Time Running
# 7916   s7917    Movie                   Sadie's Last Days on Earth
# 7936   s7937    Movie                                   Sardaar ji
# 8178   s8179    Movie                  The Accountant of Auschwitz
# 8566   s8567    Movie                         The Wrong Babysitter
#
# ...

# %%
#Number of TV Shows got the 'R' rating, after year 2018

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['category']=='TV Show') & (data['rating']=='R')]
# Out:
#      show_id category                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country date_added  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN  25-Apr-19
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway  10-Dec-16
#
#       release_year rating  duration  \
# 3893          2015      R  1 Season
# 7593          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0
# ...

# %%
data[(data['category']=='TV Show') & (data['rating']=='R') & (data['Year']>2018)]
# Out:
#      show_id category                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country date_added  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN  25-Apr-19
#
#       release_year rating  duration listed_in  \
# 3893          2015      R  1 Season  TV Shows
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
#The maximum duration of a Movie/ Shows on Netflix

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtype
# Out:
# dtype('O')

# %%
data = pd.DataFrame({'duration': ['30 minutes', '1 hour', '45 minutes']})
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand=True)

# %%
data.head()
# Out:
#      duration Minutes     Unit
# 0  30 minutes      30  minutes
# 1      1 hour       1     hour
# 2  45 minutes      45  minutes

# %%
data[['Minutes']].max()
# Out:
# Minutes    45
# dtype: object

# %%
#The country which has the highest no of TV Shows

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data_tvshow=data[data['category']=='TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id category          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa  24-Sep-21
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN  24-Sep-21
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description     Date_N    Year  \
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
# 2  To protect his family from a powerful drug lor... 2021-09-24  2021.0
#
#   Minutes     Unit
# 1       2  Seasons
# 2       1   Season

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %%
#Sort the dataset by Year.

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data.sort_values(by='Year')
# Out:
#      show_id category                         title              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by='Year',ascending = False).head(10)
# Out:
#      show_id category                               title         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
# 1002   s1003    Movie                        Tell Me When   Gerardo Gatica
# 1001   s1002    Movie                            Oloibiri    Curtis Graham
# 1000   s1001    Movie                            Wild Dog  Ahishor Solomon
# 999    s1000    Movie                            Stowaway        Joe Penna
# 998     s999    Movie                Searching For Sheela              NaN
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
#Find all the instances of
# Category is 'Movie' and Type is 'Dramas'
# OR
# Category is ' TV Show' & Type is 'Kids TV'.

# %%
data.head(2)
# Out:
#   show_id category                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# 0      90      min
# 1       2  Seasons

# %%
data[(data['category']=='Movie') & (data['listed_in']=='Dramas')]
# Out:
#      show_id category                title             director  \
# 112     s113    Movie                Worth       Sara Colangelo
# 129     s130    Movie   An Unfinished Life      Lasse Hallström
# 142     s143    Movie      Freedom Writers  Richard LaGravenese
# 162     s163    Movie             Marshall      Reginald Hudlin
# 329     s330    Movie  Catch Me If You Can     Steven Spielberg
# ...      ...      ...                  ...                  ...
# 8674   s8675    Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676    Movie               Victor    Brandon Dickerson
# 8685   s8686    Movie                  VS.             Ed Lilly
# 8691   s8692    Movie            Wakefield        Robin Swicord
# 8696   s8697    Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
data[(data['category']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id category                    title director  \
# 34       s35  TV Show  Tayo and Little Wizards      NaN
# 39       s40  TV Show             Chhota Bheem      NaN
# 65       s66  TV Show             Numberblocks      NaN
# 89       s90  TV Show              Mighty Raju      NaN
# 100     s101  TV Show  Tobot Galaxy Detectives      NaN
# ...      ...      ...                      ...      ...
# 8669   s8670  TV Show            V.R. Troopers      NaN
# 8679   s8680  TV Show       ViR: The Robot Boy      NaN
# 8783   s8784  TV Show                     Yoko      NaN
# 8785   s8786  TV Show                      YOM      NaN
# 8797   s8798  TV Show                Zak Storm      NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...
# 89    Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...
# ...

# %%
data[(data['category']=='Movie') & (data['listed_in']=='Dramas') | (data['category']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id category                    title          director  \
# 34       s35  TV Show  Tayo and Little Wizards               NaN
# 39       s40  TV Show             Chhota Bheem               NaN
# 65       s66  TV Show             Numberblocks               NaN
# 89       s90  TV Show              Mighty Raju               NaN
# 100     s101  TV Show  Tobot Galaxy Detectives               NaN
# ...      ...      ...                      ...               ...
# 8691   s8692    Movie                Wakefield     Robin Swicord
# 8696   s8697    Movie                War Horse  Steven Spielberg
# 8783   s8784  TV Show                     Yoko               NaN
# 8785   s8786  TV Show                      YOM               NaN
# 8797   s8798  TV Show                Zak Storm               NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# ...
